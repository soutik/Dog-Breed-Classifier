# %% [markdown]
# # Dog Breed Classifier
#
# In this project, I built a convolutional neural network (CNN) that can classify the breed of dog from any user-supplied image. If the image is of a human and not a dog, the algorithm will provide an estimate of the dog breed that is most resembling. The image below displays potential sample output of the finished project.

# %% [markdown]
# ## Step 1: Data Import
#
# In this step, we import the data and ready it to be used for classification

# %% [markdown]
# ### Import Dog Data

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Data

# %%
import random
random.seed(100)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ## Step 2: Detect Humans

# %% [markdown]
# ### Human Face Detector Function
#
# We will create a simple function to detect human face.

# %%
def face_detector(img_path, display = False):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    if display:
        for (x,y,w,h) in faces:
            # add bounding box to color image
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            # convert BGR image to RGB for plotting
            cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # display the image, along with bounding box
            plt.imshow(cv_rgb)
            plt.show()
    return len(faces) > 0

# Test with a random face
face_detector('lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg', True)
# Out:
# True

# %% [markdown]
# ### Testing accuracy of the face classifier
#
# Let us use the humans and dogs dataset to find how accurately our face detector works.

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]

human_count = 0.0
total = 0.0
for img in human_files_short:
    isPerson = face_detector(img)
    if not isPerson:
        human_count += 1
total = 100 - human_count
percentage = (total/len(human_files_short)) * 100.0
print('Percentage of humans correctly classified as people: {}%'.format(percentage))

dog_count = 0.0
for img in dog_files_short:
    isPerson = face_detector(img)
    if isPerson:
        dog_count += 1
percentage = (dog_count/len(dog_files_short)) * 100.0
print('Percentage of dogs misclassified as people: {}%'.format(percentage))
# Out:
# Percentage of humans correctly classified as people: 99.0%
# Percentage of dogs misclassified as people: 12.0%

# %% [markdown]
# ## Step 3: Detect Dogs
#
# We will use ResNet50 which is a pre-trained model to detect dogs in images.
#
# ResNet50 model comes in built with the Keras package.

# %%
from keras.applications.resnet50 import ResNet50
# Activate the resnet model with imagenet data
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre Process data

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # Load the image with a size of 224x224 using Keras's load_img module
    img = image.load_img(img_path, target_size=(224, 224))
    # Reshpae to (224, 224, 3) to show the RGB layer in the end
    x = image.img_to_array(img)
    # Reshape to include batches as well
    return np.expand_dims(x, axis=0)

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %%
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    # Return true if resnet says the predicted value is between 151 and 268. These are dog predictions
    return ((prediction <= 268) & (prediction >= 151))

# %%
human_count = 0.0

for img in tqdm(human_files_short):
    isDog = dog_detector(img)
    if isDog:
        human_count += 1
    percentage = (human_count/len(human_files_short)) * 100
print('Percentage of humans misclassified as dogs:: {}%'.format(percentage))

dog_count = 0.0
for img in tqdm(dog_files_short):
    isDog = dog_detector(img)
    if isDog:
        dog_count += 1
    percentage = (dog_count/len(dog_files_short)) * 100
print('Percentage of dogs correctly classified as dogs: {}%'.format(percentage))
# Out:
# 100%|██████████| 100/100 [00:30<00:00,  3.26it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Percentage of humans misclassified as dogs:: 2.0%
# 100%|██████████| 100/100 [00:26<00:00,  3.77it/s]
# Percentage of dogs correctly classified as dogs: 100.0%

# %% [markdown]
# ## Step 4: Transfer Learning
#
# We will use the bottleneck features from VGG16 network and add a fully connected layer followed by a softmax activation of the size of the number of dog breeds we have.
#
# This is called transfer learning where we take some pretrained model, add some layers and then use it in our application.

# %%
bottleneck_features = np.load('bottleneck_features/DogResnet50Data.npz')
train = bottleneck_features['train']
valid = bottleneck_features['valid']
test = bottleneck_features['test']

# %%
from keras import Sequential
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, MaxPooling2D, Flatten
from keras import regularizers

model = Sequential()
model.add(Flatten(input_shape=train.shape[1:]))
model.add(Dense(len(dog_names), activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_9 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='rmsprop', metrics=['accuracy'], loss='categorical_crossentropy')

# Save the best model to disk
from keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train, train_targets, 
          validation_data=(valid, valid_targets),
          epochs=20, batch_size=10, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6670/6680 [============================>.] - ETA: 0s - loss: 1.6023 - acc: 0.6078Epoch 00001: val_loss improved from inf to 0.85458, saving model to saved_models/weights.best.hdf5
# 6680/6680 [==============================] - 4s 634us/step - loss: 1.6012 - acc: 0.6081 - val_loss: 0.8546 - val_acc: 0.7485
# Epoch 2/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.5462 - acc: 0.8468Epoch 00002: val_loss improved from 0.85458 to 0.81507, saving model to saved_models/weights.best.hdf5
# 6680/6680 [==============================] - 3s 421us/step - loss: 0.5473 - acc: 0.8472 - val_loss: 0.8151 - val_acc: 0.7784
# Epoch 3/20
# 6610/6680 [============================>.] - ETA: 0s - loss: 0.3973 - acc: 0.8946Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 3s 418us/step - loss: 0.4049 - acc: 0.8940 - val_loss: 0.8577 - val_acc: 0.7844
# Epoch 4/20
# 6570/6680 [============================>.] - ETA: 0s - loss: 0.3194 - acc: 0.9224Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 3s 420us/step - loss: 0.3211 - acc: 0.9219 - val_loss: 0.8377 - val_acc: 0.7868
# Epoch 5/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.2684 - acc: 0.9369Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 3s 424us/step - loss: 0.2709 - acc: 0.9362 - val_loss: 0.8638 - val_acc: 0.8072
# Epoch 6/20
# 6610/6680 [============================>.] - ETA: 0s - loss: 0.2244 - acc: 0.9496Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 3s 417us/step - loss: 0.2264 - acc: 0.9493 - val_loss: 0.8421 - val_acc: 0.8084
# Epoch 7/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.1977 - acc: 0.9622Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 3s 415us/step - loss: 0.1964 - acc: 0.9623 - val_loss: 0.8430 - val_acc: 0.8275
# Epoch 8/20
# 6590/6680 [============================>.] - ETA: 0s - loss: 0.1769 - acc: 0.9692Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 3s 416us/step - loss: 0.1767 - acc: 0.9689 - val_loss: 0.8887 - val_acc: 0.8192
# Epoch 9/20
# 6570/6680 [============================>.] - ETA: 0s - loss: 0.1643 - acc: 0.9711Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 3s 420us/step - loss: 0.1624 - acc: 0.9713 - val_loss: 0.9053 - val_acc: 0.8251
# Epoch 10/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1513 - acc: 0.9761Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 3s 420us/step - loss: 0.1494 - acc: 0.9759 - val_loss: 0.9793 - val_acc: 0.8132
# Epoch 11/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1317 - acc: 0.9803Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 3s 409us/step - loss: 0.1351 - acc: 0.9799 - val_loss: 0.9876 - val_acc: 0.8216
# Epoch 12/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1309 - acc: 0.9804Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 3s 410us/step - loss: 0.1310 - acc: 0.9801 - val_loss: 0.9576 - val_acc: 0.8132
# Epoch 13/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1274 - acc: 0.9838Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 3s 425us/step - loss: 0.1264 - acc: 0.9838 - val_loss: 1.0123 - val_acc: 0.8072
# Epoch 14/20
# 6610/6680 [============================>.] - ETA: 0s - loss: 0.1227 - acc: 0.9841Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 3s 424us/step - loss: 0.1223 - acc: 0.9840 - val_loss: 1.0272 - val_acc: 0.8240
# Epoch 15/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.1161 - acc: 0.9852Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 3s 425us/step - loss: 0.1154 - acc: 0.9853 - val_loss: 1.0542 - val_acc: 0.8156
# Epoch 16/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1128 - acc: 0.9847Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 3s 424us/step - loss: 0.1125 - acc: 0.9847 - val_loss: 1.0809 - val_acc: 0.8120
# Epoch 17/20
# 6590/6680 [============================>.] - ETA: 0s - loss: 0.1121 - acc: 0.9869Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 3s 421us/step - loss: 0.1108 - acc: 0.9870 - val_loss: 1.0932 - val_acc: 0.8108
# Epoch 18/20
# 6610/6680 [============================>.] - ETA: 0s - loss: 0.1064 - acc: 0.9900Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 3s 418us/step - loss: 0.1053 - acc: 0.9901 - val_loss: 1.0938 - val_acc: 0.8120
# Epoch 19/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1028 - acc: 0.9887Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 3s 420us/step - loss: 0.1059 - acc: 0.9886 - val_loss: 1.0846 - val_acc: 0.8168
# Epoch 20/20
# 6610/6680 [============================>.] - ETA: 0s - loss: 0.1028 - acc: 0.9908Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 3s 418us/step - loss: 0.1018 - acc: 0.9909 - val_loss: 1.1255 - val_acc: 0.8084

# %% [markdown]
# ### Testing Accuracy
#
# Now lets check how our  model performs with test data

# %%
predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) for feature in test]

# report test accuracy
test_accuracy = 100*np.sum(np.array(predictions)==np.argmax(test_targets, axis=1))/len(predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 80.0000%

# %% [markdown]
# ## Step 5: Function for prediction
#
# Let's create a function that uses the models we trained above to detect the following:
# - If it's a human or a dog or neither
# - If its a dog, which breed is it
# - If its a human, which breed does it resemble the most

# %%
def predict_breed(img_path):
    from keras.applications.resnet50 import ResNet50, preprocess_input
    bottleneck_feature = ResNet50(weights='imagenet', 
                                  include_top=False).predict(preprocess_input(path_to_tensor(img_path)))
    predicted_vector = model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

def predict_dog_breed(img_path):
    is_dog = dog_detector(img_path)
    is_human = face_detector(img_path)
    if is_dog:
        return "Dog Breed: {}".format(predict_breed(img_path))
    elif is_human:
        return "Human Resembles: {}".format(predict_breed(img_path))
    else:
        return 'Error: Neither Human nor Dog Detected'

def run_image_scan(img_path):
    img = cv2.imread(img_path)
    label = predict_dog_breed(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.title(label)
    plt.show()

# %%
run_image_scan('dogImages/train/048.Chihuahua/Chihuahua_03398.jpg')

# %%
run_image_scan('test_images/soutik.png')

# %% [markdown]
# So I look like a chihuahua! Damn!
